# %%
from sqlalchemy import table
# %load_ext sql

# %%
# %sql mysql+pymysql://root:root@localhost

# %%
# %sql show databases;
# Out:
#  * mysql+pymysql://root:***@localhost
# 9 rows affected.
# [('expense_tracker',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('student',),
#  ('sys',),
#  ('test',),
#  ('world',)]

# %%
# %sql create database expense_tracker
# Out:
#  * mysql+pymysql://root:***@localhost
# 1 rows affected.
# []

# %%
# %sql use expense_tracker
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# create table expense(
# id INT AUTO_INCREMENT primary key,
# category VARCHAR(20),
# price FLOAT,
# date DATE DEFAULT(CURDATE())
# );
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# []

# %%
# %sql show tables;
# Out:
#  * mysql+pymysql://root:***@localhost
# 1 rows affected.
# [('expense',)]

# %%
# %sql DESCRIBE expense
# Out:
#  * mysql+pymysql://root:***@localhost
# 4 rows affected.
# [('id', 'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('category', 'varchar(20)', 'YES', '', None, ''),
#  ('price', 'float', 'YES', '', None, ''),
#  ('date', 'date', 'YES', '', 'curdate()', 'DEFAULT_GENERATED')]

# %%
# %sql select * from expense;
# Out:
#  * mysql+pymysql://root:***@localhost
# 4 rows affected.
# [(1, 'food', 1000.0, datetime.date(2026, 5, 9)),
#  (2, 'Movie', 2000.0, datetime.date(2026, 5, 9)),
#  (3, 'snacks', 800.0, datetime.date(2026, 5, 9)),
#  (4, 'food', 2500.0, datetime.date(2026, 5, 9))]

# %%
# %sql TRUNCATE TABLE expense
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# []
