# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql mysql+pymysql://root:root@localhost

# %%
# %sql show databases;
# Out:
#  * mysql+pymysql://root:***@localhost
# 8 rows affected.
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('student',),
#  ('sys',),
#  ('test',),
#  ('world',)]

# %%
# %sql create Database Student;
# Out:
#  * mysql+pymysql://root:***@localhost
# (pymysql.err.ProgrammingError) (1007, "Can't create database 'student'; database exists")
# [SQL: create Database Student;]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %%
# %sql use student
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# []

# %%
# %%sql
# create table student_report(
#     stud_id     VARCHAR(20) PRIMARY KEY,
#     name        VARCHAR(100),
#     classname   VARCHAR(50),
#     ai          INT,
#     web_mining  INT,
#     comp_networks INT,
#     os          INT,
#     ml          INT,
#     total       INT,
#     percentage  FLOAT,
#     grade       VARCHAR(10)
# );
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# []

# %%
# %sql show tables;
# Out:
#  * mysql+pymysql://root:***@localhost
# 1 rows affected.
# [('student_report',)]

# %%
# %sql select * from student_report
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# []

# %%
# %sql TRUNCATE TABLE student_report;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# []
