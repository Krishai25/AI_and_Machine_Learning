# %%
import sqlalchemy
print(sqlalchemy.__version__)  # must show 1.4.49
# Out:
# 1.4.49

# %%
# Cell 1
# %load_ext sql

# %%
# Cell 2
# %sql mysql+pymysql://root:root@localhost

# %%
# Cell 3
# %sql show databases;
# Out:
#  * mysql+pymysql://root:***@localhost
# 7 rows affected.
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('test',),
#  ('world',)]

# %%
# %sql use test
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# []

# %%
# %sql show tables
# Out:
#  * mysql+pymysql://root:***@localhost
# 1 rows affected.
# [('employee',)]

# %%
# %sql select * from employee;
# Out:
#  * mysql+pymysql://root:***@localhost
# 3 rows affected.
# [(1, 'John', 'IT'), (2, 'Bob', 'HR'), (3, 'Alice', 'Finance')]
