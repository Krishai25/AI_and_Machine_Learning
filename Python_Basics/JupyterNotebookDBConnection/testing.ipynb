# %%
# %load_ext sql
# %sql mysql+pymysql://root:root@localhost
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %%sql
# show DATABASES;
# Out:
#  * mysql+pymysql://root:***@localhost
# 7 rows affected.
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('test',),
#  ('world',)]

# %%
# %%sql
# use test;
# show tables;
# Out:
#  * mysql+pymysql://root:***@localhost
# 0 rows affected.
# 1 rows affected.
# [('employee',)]

# %%
# %%sql
# select * from employee
# Out:
#  * mysql+pymysql://root:***@localhost
# 3 rows affected.
# [(1, 'John', 'IT'), (2, 'Bob', 'HR'), (3, 'Alice', 'Finance')]
